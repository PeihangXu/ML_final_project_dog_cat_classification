# %% [markdown]
# # Final Project: Cats & Dogs
#
# This project is taken from Kaggle: [Cat and Dog](https://www.kaggle.com/tongpython/cat-and-dog)
#
# <img src="images/cat_dog.gif" width="600"/>
#
#
# ## Contributors:
# * Peihang Xu
# * Ryan Samimi
# * Feifan Yu

# %% [markdown]
# ---
# ## Project Files
# The compressed project zip file should contain the following files and folders:
# * Final_project_distinguish_cat_dog.ipynb
# * cat-and-dog.zip
# * requirements.txt

# %% [markdown]
# ## Setup environment
# If using conda, you can use `requirements.txt` file to setup the new environment (e.g. `final_pr`)
#
# <code>
#     $ conda create final_pr --file requirements.txt
#     $ conda activate final_pr
# </code>

# %% [markdown]
# ## Prepare dataset
# The dataset contains 10,000 pictures of cats and dogs which are compressed into `cat-and-dog.zip` file. Unzip `cat-and-dog.zip` and the dataset is ready to be used.

# %% [markdown]
# ---
# ## Imports

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
import os
import joblib
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from keras.preprocessing import image

from keras.models import Sequential                # creating sequential model of CNN
from keras.layers import Conv2D                    # creating convolution layer
from keras.layers import MaxPooling2D              # creating maxpool layer
from keras.layers import Flatten                   # creating input vector for dense layer
from keras.layers import Dense                     # create dense layer or fully connected layer
from keras.layers import Dropout                   # use to avoid overfitting by droping some params
from keras.layers import BatchNormalization        # for batch normalization
from keras.layers import Input
from keras.layers import GlobalAveragePooling2D
from keras.models import Model

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit

train_dir = 'cat-and-dog/training_set'
test_dir = 'cat-and-dog/test_set'
dumps_dir = 'dumps'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Utility functions

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate (Recall)', fontsize=16)
    plt.legend()

# %% [markdown]
# # Preprocessing Images

# %% [markdown]
# ## Image Loading function

# %%
def load_dataset(path, dim):
    """
    This function is used to load images in training and test folders
    ;param path: path to the given folder
    ;param dim: dimension used to resize the image
    """
    image_names = []
    data_labels = []
    data_images = []
    for folder in os.listdir(path):
        if folder != '.DS_Store':
            for file in os.listdir(os.path.join(path, folder)):
                if file.lower().endswith(".jpg"):
                    image_names.append(os.path.join(path, folder, file))
                    data_labels.append(folder)
                    img = cv2.imread(os.path.join(path, folder, file))
                    if dim is not None:
                        img = cv2.resize(img, dim)
                    data_images.append(img)
    return image_names, data_images, data_labels

# %% [markdown]
# ## Load images into training and test sets

# %%
# Make sure to download the dataset into the same folder as the project's pynb file. (see readme)
img_size = (64, 64)

''' Load trainging set '''
image_tr_names, data_tr_images, data_tr_labels = load_dataset(train_dir, img_size)

''' Load test set '''
image_te_names, data_te_images, data_te_labels = load_dataset(test_dir, img_size)

# %% [markdown]
# ## Verify a sample image

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(data_tr_images[10])
plt.title('A sample image of dog')
plt.axis('off')
plt.show()

# %%
# checks

data_X_tr_va = np.array(data_tr_images)
data_y_tr_va = np.array(data_tr_labels)
print(f"Number of images for cats in train set {np.count_nonzero(data_y_tr_va=='cats')}")
print(f"Number of images for dogs in train set {np.count_nonzero(data_y_tr_va=='dogs')}")

data_X_te = np.array(data_te_images)
data_y_te = np.array(data_te_labels)
print(f"Number of images for cats in test set {np.count_nonzero(data_y_te=='cats')}")
print(f"Number of images for dogs in test set {np.count_nonzero(data_y_te=='dogs')}")
# Out:
# Number of images for cats in train set 4000
# Number of images for dogs in train set 4000
# Number of images for cats in test set 1000
# Number of images for dogs in test set 1000

# %% [markdown]
# ## Processing Labels and Train-valid Splitting

# %%
# cats=0 dogs=1

data_y_tr_va[data_y_tr_va=='dogs'] = 1
data_y_tr_va[data_y_tr_va=='cats'] = 0
data_y_te[data_y_te=='dogs'] = 1
data_y_te[data_y_te=='cats'] = 0

# array([1, 2, 2]) = [int(numeric_string) for numeric_string in data_y_te]

# %%
data_y_te = data_y_te.astype(int)
data_y_tr_va = data_y_tr_va.astype(int)

# %%
strat_split = StratifiedShuffleSplit(test_size=0.15, random_state=42)
train_idx = None
valid_idx = None

for tr_idx, va_idx in strat_split.split(data_X_tr_va,data_y_tr_va):
    valid_idx = va_idx
    train_idx = tr_idx

data_X_tr = data_X_tr_va[train_idx]
data_y_tr = data_y_tr_va[train_idx]
data_X_va = data_X_tr_va[valid_idx]
data_y_va = data_y_tr_va[valid_idx]

print("X_train shape",data_X_tr.shape)
print("X_val shape",data_X_va.shape)
print("y_train shape",data_y_tr.shape)
print("y_val shape",data_y_va.shape)
print("train set dog images",np.count_nonzero(data_y_tr==0))
# Out:
# X_train shape (6800, 64, 64, 3)
# X_val shape (1200, 64, 64, 3)
# y_train shape (6800,)
# y_val shape (1200,)
# train set dog images 3400

# %%
data_X_tr = data_X_tr/255.
data_X_va = data_X_va/255.
data_X_te = data_X_te/255.

# %% [markdown]
# ---
# # Build CNN model, and train on numpy arrays

# %% [markdown]
# ## Build Model

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

classifier = Sequential([
        Conv2D(15, (3, 3), input_shape = (img_size[0],img_size[1], 3), activation = 'elu',kernel_initializer="he_uniform"),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(0.4),
        Conv2D(15, (3, 3), activation = 'elu',kernel_initializer="he_uniform"),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(0.4),
        Flatten(),
        BatchNormalization(),
        Dense(output_dim= 100, activation="elu",kernel_initializer="he_normal"),
        BatchNormalization(),
        Dense(output_dim= 1, activation='sigmoid',kernel_initializer="glorot_normal")
])

classifier.summary()
# Out:
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="elu", kernel_initializer="he_normal", units=100)`
#
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", kernel_initializer="glorot_normal", units=1)`
#   app.launch_new_instance()
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 15)        420
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 15)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31, 31, 15)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 29, 29, 15)        2040
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2940)              11760
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               294100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 308,821
# Trainable params: 302,741
# Non-trainable params: 6,080
# _________________________________________________________________

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1**(epoch / 20)

def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1**(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)

scheduler_cb = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=3)

#Although I have defined some learning rate schedulers, I did not use in the model, since I am using Adam optimizer

# %%
optimizer = tf.keras.optimizers.Adam()
classifier.compile(optimizer= optimizer, loss= 'binary_crossentropy', metrics= ['accuracy'])
# classifier.summary()

# %%
patience = 25
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss',patience=patience,restore_best_weights=True)

# %% [markdown]
# # Model Training

# %%
history = classifier.fit(data_X_tr,data_y_tr,epochs=100,validation_data=(data_X_va, data_y_va),
                    batch_size=1000,callbacks=[early_stopping_cb])
joblib.dump(history, os.path.join(dumps_dir, 'history_model_1.pkl'))

# alternatively, load the pickle file
# history = joblib.load(os.path.join('dumps', 'history_model_1.pkl'))
# Out:
# Train on 6800 samples, validate on 1200 samples
# Epoch 1/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.8369 - accuracy: 0.5374 - val_loss: 0.8228 - val_accuracy: 0.5325
# Epoch 2/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.7603 - accuracy: 0.5944 - val_loss: 1.3567 - val_accuracy: 0.5000
# Epoch 3/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.7314 - accuracy: 0.5997 - val_loss: 1.3139 - val_accuracy: 0.5000
# Epoch 4/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.6919 - accuracy: 0.6234 - val_loss: 1.0279 - val_accuracy: 0.5100
# Epoch 5/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.6721 - accuracy: 0.6363 - val_loss: 0.8634 - val_accuracy: 0.5433
# Epoch 6/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.6467 - accuracy: 0.6424 - val_loss: 0.6688 - val_accuracy: 0.6167
# Epoch 7/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.6126 - accuracy: 0.6704 - val_loss: 0.6599 - val_accuracy: 0.6225
# Epoch 8/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.6118 - accuracy: 0.6668 - val_loss: 0.6139 - val_accuracy: 0.6608
# Epoch 9/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5973 - accuracy: 0.6774 - val_loss: 0.6070 - val_accuracy: 0.6542
# Epoch 10/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5815 - accuracy: 0.6907 - val_loss: 0.5915 - val_accuracy: 0.6733
# Epoch 11/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.5646 - accuracy: 0.7038 - val_loss: 0.5852 - val_accuracy: 0.6800
# Epoch 12/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5541 - accuracy: 0.7157 - val_loss: 0.5941 - val_accuracy: 0.6942
# Epoch 13/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.5356 - accuracy: 0.7318 - val_loss: 0.6093 - val_accuracy: 0.6783
# Epoch 14/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5298 - accuracy: 0.7328 - val_loss: 0.6127 - val_accuracy: 0.6758
# Epoch 15/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5229 - accuracy: 0.7325 - val_loss: 0.6022 - val_accuracy: 0.6808
# Epoch 16/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5078 - accuracy: 0.7478 - val_loss: 0.5725 - val_accuracy: 0.7133
# Epoch 17/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.5001 - accuracy: 0.7501 - val_loss: 0.5659 - val_accuracy: 0.7067
# Epoch 18/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4943 - accuracy: 0.7585 - val_loss: 0.5555 - val_accuracy: 0.7217
# Epoch 19/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.4831 - accuracy: 0.7669 - val_loss: 0.5516 - val_accuracy: 0.7175
# Epoch 20/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4794 - accuracy: 0.7740 - val_loss: 0.5390 - val_accuracy: 0.7442
# Epoch 21/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4730 - accuracy: 0.7688 - val_loss: 0.5468 - val_accuracy: 0.7250
# Epoch 22/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4608 - accuracy: 0.7781 - val_loss: 0.5330 - val_accuracy: 0.7425
# Epoch 23/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4555 - accuracy: 0.7849 - val_loss: 0.5334 - val_accuracy: 0.7358
# Epoch 24/100
# 6800/6800 [==============================] - 10s 1ms/step - loss: 0.4542 - accuracy: 0.7824 - val_loss: 0.5247 - val_accuracy: 0.7342
# Epoch 25/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4410 - accuracy: 0.7937 - val_loss: 0.5288 - val_accuracy: 0.7417
# Epoch 26/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4275 - accuracy: 0.7976 - val_loss: 0.5254 - val_accuracy: 0.7450
# Epoch 27/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4256 - accuracy: 0.8041 - val_loss: 0.5318 - val_accuracy: 0.7425
# Epoch 28/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4150 - accuracy: 0.8138 - val_loss: 0.5228 - val_accuracy: 0.7383
# Epoch 29/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.4093 - accuracy: 0.8119 - val_loss: 0.5203 - val_accuracy: 0.7475
# Epoch 30/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3944 - accuracy: 0.8213 - val_loss: 0.5158 - val_accuracy: 0.7483
# Epoch 31/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3904 - accuracy: 0.8241 - val_loss: 0.5228 - val_accuracy: 0.7442
# Epoch 32/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.3858 - accuracy: 0.8229 - val_loss: 0.5093 - val_accuracy: 0.7408
# Epoch 33/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3731 - accuracy: 0.8334 - val_loss: 0.5231 - val_accuracy: 0.7517
# Epoch 34/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.3686 - accuracy: 0.8393 - val_loss: 0.5458 - val_accuracy: 0.7342
# Epoch 35/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3579 - accuracy: 0.8396 - val_loss: 0.5162 - val_accuracy: 0.7508
# Epoch 36/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3456 - accuracy: 0.8499 - val_loss: 0.5253 - val_accuracy: 0.7583
# Epoch 37/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3380 - accuracy: 0.8531 - val_loss: 0.5308 - val_accuracy: 0.7508
# Epoch 38/100
# 6800/6800 [==============================] - 8s 1ms/step - loss: 0.3295 - accuracy: 0.8612 - val_loss: 0.5304 - val_accuracy: 0.7550
# Epoch 39/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.3113 - accuracy: 0.8671 - val_loss: 0.5104 - val_accuracy: 0.7533
# Epoch 40/100
# 6800/6800 [==============================] - 10s 1ms/step - loss: 0.3054 - accuracy: 0.8729 - val_loss: 0.5423 - val_accuracy: 0.7600
# Epoch 41/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2993 - accuracy: 0.8754 - val_loss: 0.5237 - val_accuracy: 0.7542
# Epoch 42/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2841 - accuracy: 0.8878 - val_loss: 0.5141 - val_accuracy: 0.7642
# Epoch 43/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2764 - accuracy: 0.8899 - val_loss: 0.5442 - val_accuracy: 0.7450
# Epoch 44/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2683 - accuracy: 0.8954 - val_loss: 0.5361 - val_accuracy: 0.7567
# Epoch 45/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2548 - accuracy: 0.8978 - val_loss: 0.5355 - val_accuracy: 0.7550
# Epoch 46/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2485 - accuracy: 0.9041 - val_loss: 0.5502 - val_accuracy: 0.7550
# Epoch 47/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2371 - accuracy: 0.9121 - val_loss: 0.5560 - val_accuracy: 0.7517
# Epoch 48/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2283 - accuracy: 0.9150 - val_loss: 0.5758 - val_accuracy: 0.7550
# Epoch 49/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2073 - accuracy: 0.9276 - val_loss: 0.5343 - val_accuracy: 0.7575
# Epoch 50/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.2045 - accuracy: 0.9254 - val_loss: 0.5613 - val_accuracy: 0.7567
# Epoch 51/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1916 - accuracy: 0.9335 - val_loss: 0.6156 - val_accuracy: 0.7542
# Epoch 52/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1885 - accuracy: 0.9372 - val_loss: 0.5550 - val_accuracy: 0.7642
# Epoch 53/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1796 - accuracy: 0.9384 - val_loss: 0.6128 - val_accuracy: 0.7575
# Epoch 54/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1718 - accuracy: 0.9441 - val_loss: 0.6255 - val_accuracy: 0.7417
# Epoch 55/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1638 - accuracy: 0.9447 - val_loss: 0.6140 - val_accuracy: 0.7583
# Epoch 56/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1545 - accuracy: 0.9551 - val_loss: 0.6021 - val_accuracy: 0.7583
# Epoch 57/100
# 6800/6800 [==============================] - 9s 1ms/step - loss: 0.1452 - accuracy: 0.9578 - val_loss: 0.5812 - val_accuracy: 0.7625
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# ['dumps/history_model_1.pkl']

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.xlabel('epoch')
plt.show()

# %%
classifier.save(os.path.join(dumps_dir, 'cat-dog-model-1.h5'))
# Out:
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '

# %% [markdown]
# ## Model Performance for Test Set

# %%
classifier = keras.models.load_model(os.path.join(dumps_dir, 'cat-dog-model-1.h5'))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
y_pred_proba_test = classifier.predict(data_X_te)
y_pred_test = y_pred_proba_test>=0.5

print("ROC curve AUC:", roc_auc_score(data_y_te,y_pred_proba_test))
print('Accuracy for test set:', accuracy_score(data_y_te,y_pred_test))
# Out:
# ROC curve AUC: 0.8230790000000001
# Accuracy for test set: 0.7465

# %%
fpr_test, tpr_test, thresholds_test = roc_curve(data_y_te, y_pred_proba_test[:,0])

plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_test, tpr_test, 'test')
plt.show()

# %%
cm = confusion_matrix(data_y_te, y_pred_test)
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))
sns.heatmap(cm, 
            xticklabels=['Cat', 'Dog'],
            yticklabels=['Cat', 'Dog'],
            annot=True,ax=ax1,
            linewidths=.2,linecolor="Darkblue", cmap="Blues")
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
#  - This model is very fundamental. We just build the layers for a sequential model, compile and fit the model on the preprocessed images done by ourselves.
#  - To have faster training time, we reszie/compress the size of the images to 64x64x3, which could lose a lot of information and make the training harder.
#  - This is really a starting model, the next thing we want to try is using image generator from keras and implement data augmentation

# %% [markdown]
# ---
# # Using keras image generator for data augmentation

# %% [markdown]
# ## Image Generators

# %%
train_gen = ImageDataGenerator(rescale=1.0/255.0,
                              shear_range=0.2,
                              zoom_range=0.2,
                              rotation_range=45, #Int. degree range for random rotations.
                              width_shift_range=0.2, #fraction of total width
                              height_shift_range=0.2,#fraction of total height
                              horizontal_flip=True) #enable possible flip of images horizontally

test_gen = ImageDataGenerator(rescale = 1./255.0) #just rescale for test set, no more augmentation

imgsize = 150

X_train = train_gen.flow_from_directory(train_dir,
                                          target_size = (imgsize,imgsize),
                                          batch_size = 32,
                                          class_mode = 'binary') # For train data, select directory, sizes and import
X_test = test_gen.flow_from_directory(test_dir,
                                         target_size = (imgsize,imgsize),
                                         batch_size = 32,
                                         class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Test the idea of the generator

# %%
for X_batch,y_batch in train_gen.flow_from_directory(train_dir,
                                          target_size = (imgsize,imgsize),
                                          batch_size = 9,
                                          class_mode = 'binary'): # For train data, select directory, sizes and import
    # create a grid of 3x3 images
    plt.figure(figsize=(10,10))
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].reshape(imgsize, imgsize,3), cmap=plt.get_cmap('gray'))
        plt.title(str(y_batch[i]))
        plt.axis('off')
    # show the plot
    plt.show()
    break
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ## Build the Model

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

classifier = Sequential([
        Conv2D(32, (3, 3), input_shape = (imgsize,imgsize,3), activation = 'elu',kernel_initializer="he_uniform"),
        MaxPooling2D(pool_size=(2,2)),
#         Dropout(0.2),
        Conv2D(64, (3, 3), activation = 'elu',kernel_initializer="he_uniform"),
        MaxPooling2D(pool_size=(2,2)),
#         Dropout(0.2),
        Conv2D(64, (3, 3), activation = 'elu',kernel_initializer="he_uniform"),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        BatchNormalization(),
        Dense(output_dim= 512, activation="elu",kernel_initializer="he_normal"),
        BatchNormalization(),
        Dense(output_dim= 1, activation='sigmoid',kernel_initializer="glorot_normal")
])

classifier.summary()
# Out:
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="elu", kernel_initializer="he_normal", units=512)`
#   app.launch_new_instance()
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", kernel_initializer="glorot_normal", units=1)`
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 18496)             73984
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,603,329
# Trainable params: 9,565,313
# Non-trainable params: 38,016
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam(lr=0.001)
classifier.compile(optimizer= 'Adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# %%
patience = 30
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=patience,restore_best_weights=True)

# %% [markdown]
# # Model Training

# %%
history = classifier.fit_generator(X_train, epochs=150, validation_data=X_test,callbacks =[early_stopping_cb])
joblib.dump(history, os.path.join(dumps_dir, 'history_model_2.pkl'))

# alternatively, load the pickle file
# history = joblib.load(os.path.join('dumps', 'history_model_2.pkl'))
# Out:
# Epoch 1/150
# 250/250 [==============================] - 164s 656ms/step - loss: 0.7809 - accuracy: 0.6026 - val_loss: 1.6007 - val_accuracy: 0.5030
# Epoch 2/150
# 250/250 [==============================] - 150s 602ms/step - loss: 0.6518 - accuracy: 0.6298 - val_loss: 1.1583 - val_accuracy: 0.5935
# Epoch 3/150
# 250/250 [==============================] - 155s 622ms/step - loss: 0.6316 - accuracy: 0.6485 - val_loss: 0.7317 - val_accuracy: 0.5410
# Epoch 4/150
# 250/250 [==============================] - 155s 618ms/step - loss: 0.6146 - accuracy: 0.6649 - val_loss: 0.5919 - val_accuracy: 0.6305
# Epoch 5/150
# 250/250 [==============================] - 159s 637ms/step - loss: 0.5996 - accuracy: 0.6736 - val_loss: 0.4756 - val_accuracy: 0.7255
# Epoch 6/150
# 250/250 [==============================] - 157s 626ms/step - loss: 0.5842 - accuracy: 0.6870 - val_loss: 0.7895 - val_accuracy: 0.6365
# Epoch 7/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.5686 - accuracy: 0.7014 - val_loss: 0.4541 - val_accuracy: 0.7285
# Epoch 8/150
# 250/250 [==============================] - 158s 631ms/step - loss: 0.5574 - accuracy: 0.7131 - val_loss: 0.4986 - val_accuracy: 0.7330
# Epoch 9/150
# 250/250 [==============================] - 155s 619ms/step - loss: 0.5417 - accuracy: 0.7204 - val_loss: 0.8166 - val_accuracy: 0.6390
# Epoch 10/150
# 250/250 [==============================] - 151s 603ms/step - loss: 0.5364 - accuracy: 0.7253 - val_loss: 1.0636 - val_accuracy: 0.6145
# Epoch 11/150
# 250/250 [==============================] - 150s 599ms/step - loss: 0.5298 - accuracy: 0.7339 - val_loss: 0.3780 - val_accuracy: 0.7600
# Epoch 12/150
# 250/250 [==============================] - 152s 606ms/step - loss: 0.5172 - accuracy: 0.7354 - val_loss: 0.4870 - val_accuracy: 0.7630
# Epoch 13/150
# 250/250 [==============================] - 153s 613ms/step - loss: 0.5067 - accuracy: 0.7475 - val_loss: 0.4275 - val_accuracy: 0.7670
# Epoch 14/150
# 250/250 [==============================] - 155s 619ms/step - loss: 0.5046 - accuracy: 0.7490 - val_loss: 0.5198 - val_accuracy: 0.7465
# Epoch 15/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.4987 - accuracy: 0.7577 - val_loss: 0.2423 - val_accuracy: 0.7690
# Epoch 16/150
# 250/250 [==============================] - 160s 639ms/step - loss: 0.4882 - accuracy: 0.7602 - val_loss: 0.4431 - val_accuracy: 0.7565
# Epoch 17/150
# 250/250 [==============================] - 162s 646ms/step - loss: 0.4848 - accuracy: 0.7624 - val_loss: 0.4448 - val_accuracy: 0.7085
# Epoch 18/150
# 250/250 [==============================] - 164s 657ms/step - loss: 0.4777 - accuracy: 0.7653 - val_loss: 0.7555 - val_accuracy: 0.6300
# Epoch 19/150
# 250/250 [==============================] - 158s 633ms/step - loss: 0.4692 - accuracy: 0.7759 - val_loss: 0.1366 - val_accuracy: 0.8005
# Epoch 20/150
# 250/250 [==============================] - 146s 585ms/step - loss: 0.4704 - accuracy: 0.7774 - val_loss: 0.5083 - val_accuracy: 0.7715
# Epoch 21/150
# 250/250 [==============================] - 155s 618ms/step - loss: 0.4608 - accuracy: 0.7791 - val_loss: 0.7876 - val_accuracy: 0.7545
# Epoch 22/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.4512 - accuracy: 0.7841 - val_loss: 0.7424 - val_accuracy: 0.6790
# Epoch 23/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.4388 - accuracy: 0.7908 - val_loss: 0.4008 - val_accuracy: 0.7810
# Epoch 24/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.4460 - accuracy: 0.7894 - val_loss: 0.2025 - val_accuracy: 0.8160
# Epoch 25/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.4384 - accuracy: 0.7966 - val_loss: 0.5450 - val_accuracy: 0.8195
# Epoch 26/150
# 250/250 [==============================] - 154s 617ms/step - loss: 0.4301 - accuracy: 0.7994 - val_loss: 0.1410 - val_accuracy: 0.8220
# Epoch 27/150
# 250/250 [==============================] - 158s 631ms/step - loss: 0.4189 - accuracy: 0.8064 - val_loss: 0.3287 - val_accuracy: 0.7795
# Epoch 28/150
# 250/250 [==============================] - 158s 633ms/step - loss: 0.4197 - accuracy: 0.8051 - val_loss: 0.2912 - val_accuracy: 0.7865
# Epoch 29/150
# 250/250 [==============================] - 156s 623ms/step - loss: 0.4061 - accuracy: 0.8149 - val_loss: 0.2988 - val_accuracy: 0.8240
# Epoch 30/150
# 250/250 [==============================] - 154s 618ms/step - loss: 0.4068 - accuracy: 0.8114 - val_loss: 0.3414 - val_accuracy: 0.8335
# Epoch 31/150
# 250/250 [==============================] - 152s 606ms/step - loss: 0.3947 - accuracy: 0.8202 - val_loss: 0.2995 - val_accuracy: 0.8410
# Epoch 32/150
# 250/250 [==============================] - 150s 601ms/step - loss: 0.3976 - accuracy: 0.8202 - val_loss: 0.3822 - val_accuracy: 0.8400
# Epoch 33/150
# 250/250 [==============================] - 153s 613ms/step - loss: 0.3863 - accuracy: 0.8255 - val_loss: 0.4664 - val_accuracy: 0.8135
# Epoch 34/150
# 250/250 [==============================] - 152s 608ms/step - loss: 0.3918 - accuracy: 0.8229 - val_loss: 0.2211 - val_accuracy: 0.8170
# Epoch 35/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.3854 - accuracy: 0.8286 - val_loss: 0.1759 - val_accuracy: 0.8340
# Epoch 36/150
# 250/250 [==============================] - 150s 600ms/step - loss: 0.3728 - accuracy: 0.8325 - val_loss: 0.1946 - val_accuracy: 0.8245
# Epoch 37/150
# 250/250 [==============================] - 147s 589ms/step - loss: 0.3712 - accuracy: 0.8363 - val_loss: 0.4751 - val_accuracy: 0.8240
# Epoch 38/150
# 250/250 [==============================] - 157s 626ms/step - loss: 0.3663 - accuracy: 0.8361 - val_loss: 0.2911 - val_accuracy: 0.8540
# Epoch 39/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.3623 - accuracy: 0.8360 - val_loss: 0.9423 - val_accuracy: 0.8535
# Epoch 40/150
# 250/250 [==============================] - 162s 650ms/step - loss: 0.3585 - accuracy: 0.8453 - val_loss: 0.2947 - val_accuracy: 0.8585
# Epoch 41/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.3666 - accuracy: 0.8340 - val_loss: 0.4515 - val_accuracy: 0.8250
# Epoch 42/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.3598 - accuracy: 0.8415 - val_loss: 0.2997 - val_accuracy: 0.8115
# Epoch 43/150
# 250/250 [==============================] - 152s 608ms/step - loss: 0.3561 - accuracy: 0.8436 - val_loss: 0.2967 - val_accuracy: 0.7870
# Epoch 44/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.3452 - accuracy: 0.8504 - val_loss: 0.4433 - val_accuracy: 0.7915
# Epoch 45/150
# 250/250 [==============================] - 153s 614ms/step - loss: 0.3516 - accuracy: 0.8409 - val_loss: 0.6572 - val_accuracy: 0.8550
# Epoch 46/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.3411 - accuracy: 0.8508 - val_loss: 0.8534 - val_accuracy: 0.8090
# Epoch 47/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.3324 - accuracy: 0.8537 - val_loss: 0.3172 - val_accuracy: 0.8670
# Epoch 48/150
# 250/250 [==============================] - 151s 606ms/step - loss: 0.3469 - accuracy: 0.8462 - val_loss: 0.2229 - val_accuracy: 0.8410
# Epoch 49/150
# 250/250 [==============================] - 152s 609ms/step - loss: 0.3288 - accuracy: 0.8550 - val_loss: 0.6565 - val_accuracy: 0.8185
# Epoch 50/150
# 250/250 [==============================] - 153s 610ms/step - loss: 0.3348 - accuracy: 0.8537 - val_loss: 0.2627 - val_accuracy: 0.8610
# Epoch 51/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.3294 - accuracy: 0.8540 - val_loss: 0.3043 - val_accuracy: 0.8560
# Epoch 52/150
# 250/250 [==============================] - 152s 609ms/step - loss: 0.3282 - accuracy: 0.8529 - val_loss: 0.4020 - val_accuracy: 0.8455
# Epoch 53/150
# 250/250 [==============================] - 155s 618ms/step - loss: 0.3266 - accuracy: 0.8561 - val_loss: 0.2951 - val_accuracy: 0.8465
# Epoch 54/150
# 250/250 [==============================] - 152s 609ms/step - loss: 0.3250 - accuracy: 0.8594 - val_loss: 0.2430 - val_accuracy: 0.8400
# Epoch 55/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.3195 - accuracy: 0.8616 - val_loss: 0.1880 - val_accuracy: 0.8565
# Epoch 56/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.3132 - accuracy: 0.8631 - val_loss: 0.9633 - val_accuracy: 0.8560
# Epoch 57/150
# 250/250 [==============================] - 150s 599ms/step - loss: 0.3135 - accuracy: 0.8629 - val_loss: 0.5377 - val_accuracy: 0.8320
# Epoch 58/150
# 250/250 [==============================] - 152s 606ms/step - loss: 0.3156 - accuracy: 0.8627 - val_loss: 0.8534 - val_accuracy: 0.8425
# Epoch 59/150
# 250/250 [==============================] - 154s 618ms/step - loss: 0.3094 - accuracy: 0.8640 - val_loss: 0.3376 - val_accuracy: 0.8315
# Epoch 60/150
# 250/250 [==============================] - 153s 613ms/step - loss: 0.3024 - accuracy: 0.8687 - val_loss: 0.1874 - val_accuracy: 0.8540
# Epoch 61/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.3042 - accuracy: 0.8686 - val_loss: 0.4926 - val_accuracy: 0.8425
# Epoch 62/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.3015 - accuracy: 0.8739 - val_loss: 0.3232 - val_accuracy: 0.8140
# Epoch 63/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.3049 - accuracy: 0.8683 - val_loss: 0.4287 - val_accuracy: 0.8650
# Epoch 64/150
# 250/250 [==============================] - 156s 622ms/step - loss: 0.2953 - accuracy: 0.8708 - val_loss: 0.4533 - val_accuracy: 0.8510
# Epoch 65/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.2945 - accuracy: 0.8755 - val_loss: 0.4995 - val_accuracy: 0.8600
# Epoch 66/150
# 250/250 [==============================] - 155s 618ms/step - loss: 0.2957 - accuracy: 0.8708 - val_loss: 0.1161 - val_accuracy: 0.8620
# Epoch 67/150
# 250/250 [==============================] - 156s 625ms/step - loss: 0.2931 - accuracy: 0.8727 - val_loss: 0.2762 - val_accuracy: 0.8645
# Epoch 68/150
# 250/250 [==============================] - 157s 630ms/step - loss: 0.3036 - accuracy: 0.8674 - val_loss: 0.0946 - val_accuracy: 0.8695
# Epoch 69/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.2903 - accuracy: 0.8756 - val_loss: 0.1960 - val_accuracy: 0.8540
# Epoch 70/150
# 250/250 [==============================] - 152s 609ms/step - loss: 0.2894 - accuracy: 0.8764 - val_loss: 0.6385 - val_accuracy: 0.8670
# Epoch 71/150
# 250/250 [==============================] - 152s 609ms/step - loss: 0.2879 - accuracy: 0.8751 - val_loss: 0.3876 - val_accuracy: 0.8515
# Epoch 72/150
# 250/250 [==============================] - 151s 604ms/step - loss: 0.2910 - accuracy: 0.8737 - val_loss: 0.5270 - val_accuracy: 0.8475
# Epoch 73/150
# 250/250 [==============================] - 152s 608ms/step - loss: 0.2847 - accuracy: 0.8780 - val_loss: 0.4490 - val_accuracy: 0.8575
# Epoch 74/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.2847 - accuracy: 0.8779 - val_loss: 0.5911 - val_accuracy: 0.8305
# Epoch 75/150
# 250/250 [==============================] - 161s 643ms/step - loss: 0.2798 - accuracy: 0.8806 - val_loss: 0.6327 - val_accuracy: 0.8840
# Epoch 76/150
# 250/250 [==============================] - 172s 690ms/step - loss: 0.2814 - accuracy: 0.8792 - val_loss: 0.2152 - val_accuracy: 0.8645
# Epoch 77/150
# 250/250 [==============================] - 176s 702ms/step - loss: 0.2754 - accuracy: 0.8830 - val_loss: 0.2261 - val_accuracy: 0.8795
# Epoch 78/150
# 250/250 [==============================] - 157s 627ms/step - loss: 0.2726 - accuracy: 0.8860 - val_loss: 0.5720 - val_accuracy: 0.8775
# Epoch 79/150
# 250/250 [==============================] - 152s 607ms/step - loss: 0.2727 - accuracy: 0.8846 - val_loss: 0.4442 - val_accuracy: 0.8620
# Epoch 80/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.2786 - accuracy: 0.8841 - val_loss: 0.3622 - val_accuracy: 0.8570
# Epoch 81/150
# 250/250 [==============================] - 153s 611ms/step - loss: 0.2768 - accuracy: 0.8830 - val_loss: 0.0280 - val_accuracy: 0.8580
# Epoch 82/150
# 250/250 [==============================] - 152s 607ms/step - loss: 0.2764 - accuracy: 0.8813 - val_loss: 0.2302 - val_accuracy: 0.8525
# Epoch 83/150
# 250/250 [==============================] - 151s 605ms/step - loss: 0.2681 - accuracy: 0.8851 - val_loss: 0.4223 - val_accuracy: 0.8390
# Epoch 84/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.2753 - accuracy: 0.8813 - val_loss: 0.2598 - val_accuracy: 0.8690
# Epoch 85/150
# 250/250 [==============================] - 153s 614ms/step - loss: 0.2628 - accuracy: 0.8870 - val_loss: 0.1730 - val_accuracy: 0.8785
# Epoch 86/150
# 250/250 [==============================] - 158s 630ms/step - loss: 0.2641 - accuracy: 0.8857 - val_loss: 0.3557 - val_accuracy: 0.8640
# Epoch 87/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.2696 - accuracy: 0.8859 - val_loss: 0.5405 - val_accuracy: 0.8590
# Epoch 88/150
# 250/250 [==============================] - 154s 614ms/step - loss: 0.2683 - accuracy: 0.8857 - val_loss: 0.7316 - val_accuracy: 0.8750
# Epoch 89/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.2623 - accuracy: 0.8849 - val_loss: 0.1451 - val_accuracy: 0.8775
# Epoch 90/150
# 250/250 [==============================] - 160s 639ms/step - loss: 0.2659 - accuracy: 0.8865 - val_loss: 0.1789 - val_accuracy: 0.8535
# Epoch 91/150
# 250/250 [==============================] - 167s 667ms/step - loss: 0.2664 - accuracy: 0.8911 - val_loss: 0.5480 - val_accuracy: 0.8655
# Epoch 92/150
# 250/250 [==============================] - 166s 663ms/step - loss: 0.2564 - accuracy: 0.8919 - val_loss: 0.1751 - val_accuracy: 0.8810
# Epoch 93/150
# 250/250 [==============================] - 160s 641ms/step - loss: 0.2561 - accuracy: 0.8886 - val_loss: 0.6370 - val_accuracy: 0.8570
# Epoch 94/150
# 250/250 [==============================] - 163s 653ms/step - loss: 0.2666 - accuracy: 0.8869 - val_loss: 0.1792 - val_accuracy: 0.8700
# Epoch 95/150
# 250/250 [==============================] - 166s 665ms/step - loss: 0.2521 - accuracy: 0.8941 - val_loss: 0.5231 - val_accuracy: 0.8855
# Epoch 96/150
# 250/250 [==============================] - 163s 653ms/step - loss: 0.2528 - accuracy: 0.8982 - val_loss: 0.1668 - val_accuracy: 0.8645
# Epoch 97/150
# 250/250 [==============================] - 164s 656ms/step - loss: 0.2565 - accuracy: 0.8925 - val_loss: 0.2422 - val_accuracy: 0.8815
# Epoch 98/150
# 250/250 [==============================] - 156s 623ms/step - loss: 0.2527 - accuracy: 0.8957 - val_loss: 0.4926 - val_accuracy: 0.8550
# Epoch 99/150
# 250/250 [==============================] - 159s 636ms/step - loss: 0.2518 - accuracy: 0.8909 - val_loss: 0.4426 - val_accuracy: 0.8645
# Epoch 100/150
# 250/250 [==============================] - 171s 684ms/step - loss: 0.2582 - accuracy: 0.8903 - val_loss: 0.0603 - val_accuracy: 0.8730
# Epoch 101/150
# 250/250 [==============================] - 160s 640ms/step - loss: 0.2544 - accuracy: 0.8969 - val_loss: 0.5385 - val_accuracy: 0.8620
# Epoch 102/150
# 250/250 [==============================] - 158s 630ms/step - loss: 0.2445 - accuracy: 0.8960 - val_loss: 0.3034 - val_accuracy: 0.8805
# Epoch 103/150
# 250/250 [==============================] - 162s 647ms/step - loss: 0.2566 - accuracy: 0.8926 - val_loss: 0.2146 - val_accuracy: 0.8770
# Epoch 104/150
# 250/250 [==============================] - 157s 626ms/step - loss: 0.2452 - accuracy: 0.8949 - val_loss: 0.3169 - val_accuracy: 0.8760
# Epoch 105/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.2479 - accuracy: 0.8961 - val_loss: 0.3336 - val_accuracy: 0.8760
# Epoch 106/150
# 250/250 [==============================] - 152s 610ms/step - loss: 0.2563 - accuracy: 0.8907 - val_loss: 0.1693 - val_accuracy: 0.8800
# Epoch 107/150
# 250/250 [==============================] - 154s 617ms/step - loss: 0.2483 - accuracy: 0.8963 - val_loss: 0.0822 - val_accuracy: 0.8675
# Epoch 108/150
# 250/250 [==============================] - 155s 618ms/step - loss: 0.2394 - accuracy: 0.9020 - val_loss: 0.6098 - val_accuracy: 0.8565
# Epoch 109/150
# 250/250 [==============================] - 156s 623ms/step - loss: 0.2494 - accuracy: 0.8931 - val_loss: 0.2732 - val_accuracy: 0.8725
# Epoch 110/150
# 250/250 [==============================] - 164s 656ms/step - loss: 0.2364 - accuracy: 0.9049 - val_loss: 0.2299 - val_accuracy: 0.8645
# Epoch 111/150
# 250/250 [==============================] - 151s 604ms/step - loss: 0.2538 - accuracy: 0.8909 - val_loss: 0.4845 - val_accuracy: 0.8525
# Epoch 112/150
# 250/250 [==============================] - 151s 606ms/step - loss: 0.2399 - accuracy: 0.9001 - val_loss: 0.0268 - val_accuracy: 0.8650
# Epoch 113/150
# 250/250 [==============================] - 150s 599ms/step - loss: 0.2380 - accuracy: 0.8992 - val_loss: 0.5056 - val_accuracy: 0.8805
# Epoch 114/150
# 250/250 [==============================] - 152s 608ms/step - loss: 0.2494 - accuracy: 0.8924 - val_loss: 0.4968 - val_accuracy: 0.8795
# Epoch 115/150
# 250/250 [==============================] - 150s 598ms/step - loss: 0.2434 - accuracy: 0.8953 - val_loss: 0.2249 - val_accuracy: 0.8860
# Epoch 116/150
# 250/250 [==============================] - 151s 603ms/step - loss: 0.2295 - accuracy: 0.9075 - val_loss: 1.5305 - val_accuracy: 0.8775
# Epoch 117/150
# 250/250 [==============================] - 149s 598ms/step - loss: 0.2508 - accuracy: 0.8972 - val_loss: 0.1331 - val_accuracy: 0.8900
# Epoch 118/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.2446 - accuracy: 0.8954 - val_loss: 0.0794 - val_accuracy: 0.8785
# Epoch 119/150
# 250/250 [==============================] - 153s 612ms/step - loss: 0.2310 - accuracy: 0.9005 - val_loss: 0.1456 - val_accuracy: 0.8795
# Epoch 120/150
# 250/250 [==============================] - 154s 617ms/step - loss: 0.2369 - accuracy: 0.9016 - val_loss: 0.1761 - val_accuracy: 0.8750
# Epoch 121/150
# 250/250 [==============================] - 154s 618ms/step - loss: 0.2335 - accuracy: 0.9018 - val_loss: 0.3790 - val_accuracy: 0.8795
# Epoch 122/150
# 250/250 [==============================] - 155s 620ms/step - loss: 0.2254 - accuracy: 0.9057 - val_loss: 0.0470 - val_accuracy: 0.8570
# Epoch 123/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.2330 - accuracy: 0.9031 - val_loss: 0.4279 - val_accuracy: 0.8695
# Epoch 124/150
# 250/250 [==============================] - 154s 615ms/step - loss: 0.2296 - accuracy: 0.9044 - val_loss: 1.5376 - val_accuracy: 0.8670
# Epoch 125/150
# 250/250 [==============================] - 154s 616ms/step - loss: 0.2312 - accuracy: 0.9029 - val_loss: 0.2444 - val_accuracy: 0.8605
# Epoch 126/150
# 250/250 [==============================] - 160s 642ms/step - loss: 0.2309 - accuracy: 0.9045 - val_loss: 0.0185 - val_accuracy: 0.8685
# Epoch 127/150
# 250/250 [==============================] - 169s 676ms/step - loss: 0.2450 - accuracy: 0.8971 - val_loss: 0.0620 - val_accuracy: 0.8590
# Epoch 128/150
# 250/250 [==============================] - 168s 672ms/step - loss: 0.2288 - accuracy: 0.9040 - val_loss: 0.2565 - val_accuracy: 0.8635
# Epoch 129/150
# 250/250 [==============================] - 166s 664ms/step - loss: 0.2332 - accuracy: 0.9049 - val_loss: 0.0831 - val_accuracy: 0.8760
# Epoch 130/150
# 250/250 [==============================] - 164s 655ms/step - loss: 0.2224 - accuracy: 0.9060 - val_loss: 0.2896 - val_accuracy: 0.8795
# Epoch 131/150
# 250/250 [==============================] - 163s 650ms/step - loss: 0.2259 - accuracy: 0.9072 - val_loss: 0.4145 - val_accuracy: 0.8895
# Epoch 132/150
# 250/250 [==============================] - 165s 660ms/step - loss: 0.2229 - accuracy: 0.9068 - val_loss: 0.3858 - val_accuracy: 0.8770
# Epoch 133/150
# 250/250 [==============================] - 167s 667ms/step - loss: 0.2336 - accuracy: 0.9031 - val_loss: 0.4721 - val_accuracy: 0.8435
# Epoch 134/150
# 250/250 [==============================] - 166s 666ms/step - loss: 0.2236 - accuracy: 0.9040 - val_loss: 0.5588 - val_accuracy: 0.8525
# Epoch 135/150
# 250/250 [==============================] - 167s 667ms/step - loss: 0.2255 - accuracy: 0.9072 - val_loss: 0.1992 - val_accuracy: 0.8915
# Epoch 136/150
# 250/250 [==============================] - 163s 652ms/step - loss: 0.2280 - accuracy: 0.9028 - val_loss: 0.0491 - val_accuracy: 0.8725
# Epoch 137/150
# 250/250 [==============================] - 169s 675ms/step - loss: 0.2197 - accuracy: 0.9099 - val_loss: 0.2289 - val_accuracy: 0.8825
# Epoch 138/150
# 250/250 [==============================] - 156s 624ms/step - loss: 0.2284 - accuracy: 0.9053 - val_loss: 0.4746 - val_accuracy: 0.8915
# Epoch 139/150
# 250/250 [==============================] - 164s 657ms/step - loss: 0.2231 - accuracy: 0.9070 - val_loss: 0.1048 - val_accuracy: 0.8730
# Epoch 140/150
# 250/250 [==============================] - 163s 651ms/step - loss: 0.2260 - accuracy: 0.9053 - val_loss: 0.2754 - val_accuracy: 0.8905
# Epoch 141/150
# 250/250 [==============================] - 163s 652ms/step - loss: 0.2192 - accuracy: 0.9080 - val_loss: 0.1102 - val_accuracy: 0.8925
# Epoch 142/150
# 250/250 [==============================] - 165s 660ms/step - loss: 0.2191 - accuracy: 0.9082 - val_loss: 0.2076 - val_accuracy: 0.8935
# Epoch 143/150
# 250/250 [==============================] - 164s 656ms/step - loss: 0.2151 - accuracy: 0.9114 - val_loss: 0.3100 - val_accuracy: 0.8895
# Epoch 144/150
# 250/250 [==============================] - 172s 690ms/step - loss: 0.2190 - accuracy: 0.9111 - val_loss: 0.3345 - val_accuracy: 0.8780
# Epoch 145/150
# 250/250 [==============================] - 166s 665ms/step - loss: 0.2217 - accuracy: 0.9082 - val_loss: 0.6786 - val_accuracy: 0.8490
# Epoch 146/150
# 250/250 [==============================] - 178s 712ms/step - loss: 0.2193 - accuracy: 0.9086 - val_loss: 0.4735 - val_accuracy: 0.8705
# Epoch 147/150
# 250/250 [==============================] - 162s 648ms/step - loss: 0.2108 - accuracy: 0.9137 - val_loss: 0.4666 - val_accuracy: 0.8925
# Epoch 148/150
# 250/250 [==============================] - 162s 650ms/step - loss: 0.2175 - accuracy: 0.9070 - val_loss: 0.6045 - val_accuracy: 0.8765
# Epoch 149/150
# 250/250 [==============================] - 166s 664ms/step - loss: 0.2282 - accuracy: 0.9064 - val_loss: 1.0240 - val_accuracy: 0.8770
# Epoch 150/150
# 250/250 [==============================] - 164s 658ms/step - loss: 0.2164 - accuracy: 0.9081 - val_loss: 0.1436 - val_accuracy: 0.8870
# ['dumps/history_model_2.pkl']

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.grid(True)
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
classifier.save(os.path.join(dumps_dir, 'cats-dogs-model-2.h5'))

# %% [markdown]
# ## Model Performance for Test Set

# %%
classifier = keras.models.load_model(os.path.join(dumps_dir, 'cats-dogs-model-2.h5'))
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# prepare test data for img size 150x150
imgsize = 150
img_size = (imgsize,imgsize)
image_te_names, data_te_images, data_te_labels = load_dataset(test_dir, img_size)
data_X_te = np.array(data_te_images)
data_y_te = np.array(data_te_labels)
data_y_te[data_y_te=='dogs'] = 1
data_y_te[data_y_te=='cats'] = 0
data_y_te = data_y_te.astype(int)
data_X_te = np.array(data_te_images)/255.
data_X_te.shape
# Out:
# (2000, 150, 150, 3)

# %%
y_pred_proba_test = classifier.predict(data_X_te)
y_pred_test = y_pred_proba_test>=0.5

print("ROC curve AUC:", roc_auc_score(data_y_te,y_pred_proba_test))
print("Accuracy for test set:", accuracy_score(data_y_te,y_pred_test))
# Out:
# ROC curve AUC: 0.9155979999999999
# Accuracy for test set: 0.84

# %%
fpr_test, tpr_test, thresholds_test = roc_curve(data_y_te, y_pred_proba_test)

plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_test, tpr_test, 'test')
plt.show()

# %%
cm = confusion_matrix(data_y_te, y_pred_proba_test>0.5)
# cm = confusion_matrix(df_y_train, RF_clf_proba[:,1]>=0.5)
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))
sns.heatmap(cm, 
            xticklabels=['Not Default', 'Default'],
            yticklabels=['Not Default', 'Default'],
            annot=True,ax=ax1,
            linewidths=.2,linecolor="Darkblue", cmap="Blues")
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# - This model performs much better with data augmentation
# - Also image size used for this model is slightly bigger: 150x150x3

# %% [markdown]
# ---
# # Transfer Learning

# %% [markdown]
# ## Build Model

# %%
from keras.applications import mobilenet
from keras.applications.mobilenet import preprocess_input
from keras.models import Sequential, Model, Input

# %%
imgsize = 224

X_train_trans = train_gen.flow_from_directory(train_dir,
                                          target_size = (imgsize,imgsize),
                                          batch_size = 32,
                                          class_mode = 'binary') # For train data, select directory, sizes and import
X_test_trans = test_gen.flow_from_directory(test_dir,
                                         target_size = (imgsize,imgsize),
                                         batch_size = 32,
                                         class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
mobilenet_model = mobilenet.MobileNet(input_shape = (imgsize, imgsize, 3), weights='imagenet', include_top=False)

# %%
mobilenet_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
inputs = Input(shape=(imgsize, imgsize, 3))
x = mobilenet_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x) # we add dense layers so that the model can learn more complex functions and classify for better results.
x = Dropout(0.5)(x) # to avoid overfitting
x = Dense(512, activation='relu')(x) # dense layer 2

outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=outputs)

model.layers[1].trainable = True

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# mobilenet_1.00_224 (Model)   (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,803,777
# Trainable params: 4,781,889
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# Try to make only the whole block 13 trainable for MobileNet

mbn_layers = np.array(model.layers[1].layers).shape[0]
for index,l in enumerate(model.layers[1].layers):
     if index <= mbn_layers-6:
            l.trainable=False
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# mobilenet_1.00_224 (Model)   (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,803,777
# Trainable params: 2,627,585
# Non-trainable params: 2,176,192
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(optimizer = optimizer, loss= 'binary_crossentropy', metrics= ['accuracy'])

history = model.fit_generator(X_train_trans, epochs= 3, 
                              validation_data = X_test_trans)
joblib.dump(history, os.path.join(dumps_dir, 'history_model_3.pkl'))

# alternatively, load the pickle file
# history = joblib.load(os.path.join('dumps', 'history_model_3.pkl'))
# Out:
# Epoch 1/3
# 250/250 [==============================] - 427s 2s/step - loss: 0.1719 - accuracy: 0.9345 - val_loss: 0.0066 - val_accuracy: 0.9805
# Epoch 2/3
# 250/250 [==============================] - 426s 2s/step - loss: 0.1037 - accuracy: 0.9603 - val_loss: 0.0140 - val_accuracy: 0.9860
# Epoch 3/3
# 250/250 [==============================] - 432s 2s/step - loss: 0.0975 - accuracy: 0.9628 - val_loss: 0.0283 - val_accuracy: 0.9660
# /Users/peihangxu/opt/anaconda3/envs/TF/lib/python3.7/site-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# ['dumps/history_model_3.pkl']

# %%
model.save(os.path.join(dumps_dir, 'cats-and-dogs-transfer-model.h5'))

# %% [markdown]
# ## Model Performance for Test Set

# %%
model = tf.keras.models.load_model(os.path.join(dumps_dir, 'cats-and-dogs-transfer-model.h5'))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# prepare test data for img size 224x224
imgsize = 224
img_size = (imgsize,imgsize)
image_te_names, data_te_images, data_te_labels = load_dataset(test_dir, img_size)
data_X_te = np.array(data_te_images)
data_y_te = np.array(data_te_labels)
data_y_te[data_y_te=='dogs'] = 1
data_y_te[data_y_te=='cats'] = 0
data_y_te = data_y_te.astype(int)
data_X_te = np.array(data_te_images)/255.
data_X_te.shape
# Out:
# (2000, 224, 224, 3)

# %%
y_pred_proba_test = model.predict(data_X_te)
y_pred_test = y_pred_proba_test>=0.5

print("ROC curve AUC:", roc_auc_score(data_y_te,y_pred_proba_test))
print("Accuracy for test set:", accuracy_score(data_y_te,y_pred_test))
# Out:
# ROC curve AUC: 0.998166
# Accuracy for test set: 0.9645

# %%
fpr_test, tpr_test, thresholds_test = roc_curve(data_y_te, y_pred_proba_test)

plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_test, tpr_test, 'test')
plt.show()

# %%
cm = confusion_matrix(data_y_te, y_pred_proba_test>0.5)
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))
sns.heatmap(cm, 
            xticklabels=['Cat', 'Dog'],
            yticklabels=['Cat', 'Dog'],
            annot=True,ax=ax1,
            linewidths=.2,linecolor="Darkblue", cmap="Blues")
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# - Boom! Transferlearning is amazing!
# - Actually we do not need to train many epochs to get good results!
# - It definitely takes longer for each epoch since there are more training parameters!

# %% [markdown]
# # Future works

# %% [markdown]
# - This model in gerneral is solving a simple problem: binary classification
# - With the efficiency from transfer learning, we could build up a model dealing with multi-label image classification
# - Next reasonable thing to try is GPU training, considering that TensorFlow supports GPU. This would lead to way faster training!
